# %%
60 * 60
# Out:
# 3600

# %%
seconds_per_hour = 3600

# %%
seconds_per_hour * 24
# Out:
# 86400

# %%
seconds_per_day = seconds_per_hour * 24

# %%
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %%
seconds_per_day // seconds_per_hour
# Out:
# 24

# %% [markdown]
# The integer value agrees with the floating-point value, aside from the final .0
