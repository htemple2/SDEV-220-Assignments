# %% [markdown]
# Chapter 7 Questions

# %%
things = ["mozzarella", "cinderella", "salmonella"]

# %%
things[1] = "Cinderella"
things
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %% [markdown]
# "cinderella" was changed to "Cinderella"

# %%
things[0] = "MOZZARELLA"
things
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %%
del things[2]
things
# Out:
# ['MOZZARELLA', 'Cinderella']

# %% [markdown]
# Chapter 9 Questions

# %%
def good():
    return ["Harry", "Ron", "Hermione"]

# %%
def get_odds():
    for x in range(10):
        if x % 2 != 0:
            yield x

for odd in get_odds():
    odd_list = list(get_odds())
print(f"Odds: {odd_list}")
print(f"Third value of odds: {odd_list[2]}")
# Out:
# Odds: [1, 3, 5, 7, 9]
# Third value of odds: 5
