# %%
class Solution:
    def sort012(self, arr):
        low = 0
        mid = 1
        high = len(arr) - 1

        while mid <= high:
            if arr[mid] == 0:
                arr[low], arr[mid] = arr[mid], arr[low]
                low += 1
                mid += 1
            elif arr[mid] == 1:
                mid += 1
            else:
                arr[mid], arr[high] = arr[high], arr[mid]
                high -= 1
        return arr

# %%
if __name__ == "__main__":
    import numpy as np #type: ignore
    choices = [0, 1, 2]
    arr = np.random.choice(choices, size=7)
    print("Original array: ", arr)
    solution = Solution()
    sorted_arr = solution.sort012(arr)
    print("Sorted array: ", sorted_arr)
# Out:
# Original array:  [1 0 2 2 1 2 2]
# Sorted array:  [0 1 1 2 2 2 2]
